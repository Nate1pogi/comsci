# %% [markdown]
# <a href="https://colab.research.google.com/github/Nate1pogi/comsci/blob/main/fa4program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 1: Even Number Skipper

for i in range(1, 21):
    if i % 2 == 0:  # Check if the number is even
        continue    # Skip to the next iteration if even
    print(i)

# %%
# Problem 2: Password Checker

correct_password = "ColabRocks"
max_attempts = 3
attempts = 0

while True:
    if attempts >= max_attempts:
        print("Too many incorrect attempts. Access denied.")
        break

    password = input("Enter the password: ")

    if password == correct_password:
        print("Access granted! Welcome.")
        break  # Exit the loop if password is correct
    else:
        attempts += 1
        print(f"Incorrect password. Please try again. ({max_attempts - attempts} attempts remaining)")

# %%
# Problem 3: Number Filter Display

for i in range(1, 11):
    if i == 4:
        continue  # Skip number 4
    elif i == 6:
        pass      # Do nothing special for number 6
    elif i == 8:
        print(f"Stopping loop at number {i}")
        break     # Stop the loop completely at 8
    print(i)
